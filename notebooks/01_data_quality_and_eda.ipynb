# %% [markdown]
# # 01 — Data quality and exploratory analysis
#
# This notebook is a beginner-friendly walkthrough. It calls tested project functions instead of duplicating business logic. Keep the workbook private in `data/raw/`.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))

from european_bank_churn import (
    load_excel, overall_kpis, prepare_data, segment_summary, validate_dataset
)

# %%
WORKBOOK = PROJECT_ROOT / 'data' / 'raw' / 'European_Bank.xlsx'
raw = load_excel(WORKBOOK)
raw.shape

# %%
validate_dataset(raw)

# %%
data, thresholds = prepare_data(raw)
overall_kpis(data), thresholds

# %%
geography = segment_summary(data, 'Geography')
geography.sort_values('ChurnRate', ascending=False)

# %% [markdown]
# ## Interpretation checklist
#
# - Report counts with percentages.
# - Treat differences as associations, not causes.
# - Investigate small groups before recommending action.
# - Do not commit executed output containing customer rows.
